# %%
class BTNode:
  def __init__(self, elem):
    self.elem = elem
    self.right = None
    self.left = None

# %%
def inorder(root):
  if root == None:
    return

  inorder(root.left)
  print(root.elem, end = ' ')
  inorder(root.right)

# %%
def tree_construction(arr, i = 1):
  if i>=len(arr) or arr[i] == None:
    return None
  p = BTNode(arr[i])
  p.left = tree_construction(arr, 2*i)
  p.right = tree_construction(arr, 2*i+1)
  return p


root2 = tree_construction([None, 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', None, None, None, 'I', 'J', None, 'k'])
inorder(root2)
# Out:
# H D B E A I F J C G k

# %% [markdown]
# Task 1

# %%
def convert_mirror(root):
  #pass
  if root == None:
    return
  left = root.left
  right = root.right
  root.left = convert_mirror(right)
  root.right = convert_mirror(left)
  return root


#DRIVER CODE
root = BTNode(10)
n1 = BTNode(20)
n2 = BTNode(30)
n3 = BTNode(40)
n4 = BTNode(60)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  40 20 60 10 30
print()

root2 = convert_mirror(root)
print('Mirrored Tree Inorder Traversal: ', end = ' ')
inorder(root2) #Mirrored Tree Inorder Traversal:  30 10 60 20 40
# Out:
# Given Tree Inorder Traversal:  40 20 60 10 30
# Mirrored Tree Inorder Traversal:  30 10 60 20 40

# %% [markdown]
# Task 2

# %%
def smallest_level(root):
  # List<List<Integer>> result = new ArrayList<>();
  if root == None:
    return 0
  result = {}
  final = []
  final.append(root)
  count = 0
  while len(final) !=0:
    count += 1
    level = len(final)
    levelList = []
    for i in range(level):
      cur = final[0]
      final = final[1:]
      levelList.append(cur.elem)
      if cur.left != None:
        final.append(cur.left)
      if cur.right != None:
        final.append(cur.right)
    temp = min(levelList)
    result[count-1] = temp
  return result

#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %%
def smallest_level(root,level=0,dic={}):
  if root!=None:
    if level not in dic:
      dic[level]=root.elem
    else:
      if dic[level]>root.elem:
        dic[level]=root.elem
    smallest_level(root.left,level+1,dic)
    smallest_level(root.right,level+1,dic)

  return dic
#DRIVER CODE
root = tree_construction([None, 4,9,2,3,-5,None,7])
print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  3 9 5 4 2 7
print()
print('Level Wise Smallest Value: ', end = ' ')
print(smallest_level(root)) #Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}
# Out:
# Given Tree Inorder Traversal:  3 9 -5 4 2 7
# Level Wise Smallest Value:  {0: 4, 1: 2, 2: -5}

# %% [markdown]
# Task 3

# %%
def inorder_predecessor(root, x):
  if root == None:
    return

  pred = None
  while (root != None):
    if (x.elem > root.elem):
      pred = root
      root = root.right
    else:
    
      root = root.left
  return pred


#DRIVER CODE
root = BTNode(20)
n1 = BTNode(8)
n2 = BTNode(22)
n3 = BTNode(4)
n4 = BTNode(12)
n5 = BTNode(10)
n6 = BTNode(14)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n4.left = n5
n4.right = n6

print('Given Tree Inorder Traversal: ', end = ' ')
inorder(root) #Given Tree Inorder Traversal:  4 8 10 12 14 20 22
print()

x = root
print(f'Inorder predecessor of node {x.elem}: {inorder_predecessor(root, x).elem}') #Inorder predecessor of node 20: 14
# Out:
# Given Tree Inorder Traversal:  4 8 10 12 14 20 22
# Inorder predecessor of node 20: 14

# %% [markdown]
# Task 4

# %%
def LCA(root, x, y):
  if root == None:
            return None
        
  if (root.elem == x or root.elem == y):
    return root
    
  left = LCA(root.left, x, y)
  right = LCA(root.right, x, y)


  if (left != None and right != None):
    return root
  if (left == None):
    return right
    
  return left

#DRIVER CODE
root = BTNode(15)
n1 = BTNode(10)
n2 = BTNode(25)
n3 = BTNode(8)
n4 = BTNode(12)
n5 = BTNode(20)
n6 = BTNode(30)
n7 = BTNode(6)
n8 = BTNode(9)
n9 = BTNode(18)
n10 = BTNode(22)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4

n3.left = n7
n3.right = n8
n2.left = n5
n2.right = n6
n5.left = n9
n5.right = n10
#Write by yourself from the given tree
print(f"Lowest Common Ancestor of {n7.elem} and {n4.elem} is: ",LCA(root, 6,12).elem)           #=10 
print(f"Lowest Common Ancestor of {n5.elem} and {n7.elem} is: ",LCA(root, 20,6).elem)           #=15 
print(f"Lowest Common Ancestor of {n9.elem} and {n10.elem} is: ",LCA(root, 18,22).elem)           #=20 
print(f"Lowest Common Ancestor of {n5.elem} and {n2.elem} is: ",LCA(root, 20,25).elem)           #=25 
print(f"Lowest Common Ancestor of {n1.elem} and {n4.elem} is: ",LCA(root, 10,12).elem)           #=10
#check all the sample inputs given
# Out:
# Lowest Common Ancestor of 6 and 12 is:  10
# Lowest Common Ancestor of 20 and 6 is:  15
# Lowest Common Ancestor of 18 and 22 is:  20
# Lowest Common Ancestor of 20 and 25 is:  25
# Lowest Common Ancestor of 10 and 12 is:  10

# %% [markdown]
# BONUS TASK 1

# %%
#WRITE THE FUNCTION and DRIVER CODE BY YOURSELF
def SumTree(root, sum = 0):
  if root == None:
    return 0

  
  sum = root.elem + SumTree(root.left, sum) + SumTree(root.right, sum)
  if sum == root.elem:
    return True
  return False


root = BTNode(26)
n1 = BTNode(10)
n2 = BTNode(3)
n3 = BTNode(4)
n4 = BTNode(6)
n5 = BTNode(3)

root.left = n1
root.right = n2

n1.left = n3
n1.right = n4
n2.right = n5


print("Is sum of left subtree and right subtree equal to root?",SumTree(root))
# Out:
# Is sum of left subtree and right subtree equal to root? True

# %% [markdown]
# Bonus Task 2

# %%
#WRITE THE FUNCTION BY YOURSELF
def sumDifference(root):
  if root == None:
    return 0
  result = 0
  final = []
  final.append(root)
  count = 0
  while len(final) !=0:
    count += 1
    level = len(final)
    levelList = []
    for i in range(level):
      cur = final[0]
      final = final[1:]
      levelList.append(cur.elem)
      if cur.left != None:
        final.append(cur.left)
      if cur.right != None:
        final.append(cur.right)
    temp = sum(levelList)
    result = temp - result
  return result

#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8


print(sumDifference(root))
# Out:
# 4

# %%
#WRITE THE FUNCTION BY YOURSELF
def sumDifference(root):
  if root == None:
    return 0
  result = 0
  final = {}
  final[root.elem] = root
  count = 0
  flag = root
  while len(final) !=0:
    count += 1
    level = len(final)
    levelList = {}
    for i in range(level):
      cur = final.pop(list(final.keys())[0])
      levelList[cur.elem] = cur
      if cur.left != None:
        final[cur.left.elem] = cur.left
      if cur.right != None:
        final[cur.right.elem] = cur.right
    temp = sum(levelList)
    result = temp - result
  return result

#DRIVER CODE
root = BTNode(1)
n2 = BTNode(2)
n3 = BTNode(3)
n4 = BTNode(4)
n5 = BTNode(5)
n6 = BTNode(6)
n7 = BTNode(7)
n8 = BTNode(8)
root.left = n2
root.right = n3

n2.left = n4
n3.left = n5
n3.right = n6

n5.left = n7
n5.right = n8


print(sumDifference(root))
# Out:
# 4
